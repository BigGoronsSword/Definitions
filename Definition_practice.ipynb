# %%
def guess_blue(blue_start, red_start, blue_pulled, red_pulled):
    total = blue_start + red_start - blue_pulled - red_pulled
    return float(blue_start - blue_pulled) / total
    
print(guess_blue(6,6,0,1))
# Out:
# 0.5454545454545454

# %%
def greet(person):
    # Line 4 is where the magic happens.
    person = person or 'world'
    return "Hello " + person

# Can you guess what the values below are before printing them?
greeting_1 = greet('Guido')
greeting_2 = greet('')
greeting_3 = greet(None)

print(greeting_1)
print(greeting_2)
print(greeting_3)
# Out:
# Hello Guido
# Hello world
# Hello world

# %%
def box_capacity(length, width, height):  
    return (length * 12 // 16) * (width * 12 // 16) * (height * 12 // 16)
 

print(box_capacity(32,64,16))
# Out:
# 13824

# %% [markdown]
# Congo recently standardized its storage containers: all pizzas fit inside a cubic crate, 16-inchs on a side.  return an integer representing the number of boxes you can store in that space.
#
# For example: a warehouse 32 feet long, 64 feet wide, and 16 feet high can hold 13,824 boxes because you can fit 24 boxes across, 48 boxes deep, and 12 boxes high, so box_capacity(32, 64, 16) should return 13824.

# %%
def greet_jedi(first="grace", last="flynn"):
    f_slice = slice(2)
    l_slice = slice(3)
    jedi_first = first[f_slice].capitalize()
    jedi_last = last[l_slice].capitalize()
    jedi_name = jedi_last + jedi_first
    return ("Greetings, master "+ jedi_name)
 
first = "grace"
last = "flynn"

print (greet_jedi(first, last))
# Out:
# Greetings, master FlyGr

# %% [markdown]
# You need a function to handle each change from green, to yellow, to red, and then to green again.
#
# Complete the function that takes a string as an argument representing the current state of the light and returns a string representing the state the light should change to.
#
# For example, update_light('green') should return 'yellow'.

# %%
def update_light(current):
    if current == "green":
      return "yellow"
    elif current == "yellow":
          return "red"
    elif current == "red":
      return "green"
          
          
print(update_light("red"))
# Out:
# green

# %% [markdown]
# Anything that represents "something" is true. Anything that represents "nothing" is false:

# %%
def take_umbrella(weather, rain_chance):
    if weather == "rainy":
      return True
    if rain_chance >.50:
      return True
    if weather == "sunny": 
      return False
    if weather == "cloudy" and rain_chance >.2:
      return True
    else:
      return False

    
print(take_umbrella("cloudy", .5))
# Out:
# True
